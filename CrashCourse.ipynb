# %%
message = "Hello World"

print(message)
# Out:
# Hello World

# %%
name = "ada lovelace"
print(name.title())
# Out:
# Ada Lovelace

# %%
f_name = 'Ada'
l_name ='Lovelace' 
full_name = f"Hello! \n\t{f_name} {l_name}"

print(full_name)
# Out:
# Hello!
# 	Ada Lovelace

# %% [markdown]
# ### Using conditional statements within an f string

# %%
num = 87;
print(f"Is num even? {True if num%2==0 else False}")
# Out:
# Is num even? False

# %% [markdown]
# ### Using methods within an f string

# %%
author = "jane smith"
print(f"This is a book by {author.title()}.")
# Out:
# This is a book by Jane Smith.

# %% [markdown]
# ### Using functions within an f string

# %%
def choice(c):
  if c%2 ==0:
    return "Learn Python!"
  else:
    return "Learn JavaScript!"

print(f"Hello Python, tell me what I should learn. {choice(3)}")
# Out:
# Hello Python, tell me what I should learn. Learn JavaScript!

# %% [markdown]
# ### Aligning text within an f string
#
#
# ![image.png](attachment:image.png)

# %%
import math
variable = math.pi
print(f"Using Numeric {variable = }")
print(f"|{variable:25}|")
print(f"|{variable:<25}|")
print(f"|{variable:>25}|")
print(f"|{variable:^25}|\n")
variable = "Python 3.9"
print(f"Using String {variable = }")
print(f"|{variable:25}|")
print(f"|{variable:<25}|")
print(f"|{variable:>25}|")
print(f"|{variable:^25}|")
# Out:
# Using Numeric variable = 3.141592653589793
# |        3.141592653589793|
# |3.141592653589793        |
# |        3.141592653589793|
# |    3.141592653589793    |
#
# Using String variable = 'Python 3.9'
# |Python 3.9               |
# |Python 3.9               |
# |               Python 3.9|
# |       Python 3.9        |

# %% [markdown]
# ### Working with datatypes in an f string
#
# ![image.png](attachment:image.png)

# %%
nostarch_url = "https://nostarch.com"
nostarch_url.removeprefix('https://')
# Out:
# 'nostarch.com'

# %%
bicycles = ['trek','cannondale','redldne','specialized']

bicycles[0]
# Out:
# 'trek'

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
motorcycles[0]='ducati'
motorcycles.append('honda')
motorcycles.insert(0,'harley')
#del motorcycles[0]
popped_motorcycle = motorcycles.pop()
popped_motorcycle
# Out:
# 'honda'

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()
print(cars)
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(magician)
# Out:
# alice
# david
# carolina

# %%
squares = []
for value in range(1,11):
    squares.append(value**2)

print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares = [value**2 for value in range(1,101) if value%2==0]

squares
# Out:
# [4,
#  16,
#  36,
#  64,
#  100,
#  144,
#  196,
#  256,
#  324,
#  400,
#  484,
#  576,
#  676,
#  784,
#  900,
#  1024,
#  1156,
#  1296,
#  1444,
#  1600,
#  1764,
#  1936,
#  2116,
#  2304,
#  2500,
#  2704,
#  2916,
#  3136,
#  3364,
#  3600,
#  3844,
#  4096,
#  4356,
#  4624,
#  4900,
#  5184,
#  5476,
#  5776,
#  6084,
#  6400,
#  6724,
#  7056,
#  7396,
#  7744,
#  8100,
#  8464,
#  8836,
#  9216,
#  9604,
#  10000]

# %%
players = ['charles', 'martina', 'michael', 'florence', 'eli']
print(players[0:3])
# Out:
# ['charles', 'martina', 'michael']

# %%
available_toppings = ['mushrooms', 'olives', 'green peppers',
'pepperoni', 'pineapple', 'extra cheese']
#requested_toppings = ['mushrooms', 'french fries', 'extra cheese']
requested_toppings = []
if requested_toppings:
    for requested_topping in requested_toppings:
        if requested_topping in available_toppings:
            print(f"Adding {requested_topping} to the order")
        else:
            print(f"Sorry you can't add {requested_topping} to your pizza")
    print(f"\nFinished making your pizza")
else: print("Are you sure you want a plain pizza?")
# Out:
# Are you sure you want a plain pizza?

# %%
alien_0 = {'x_position': 0, 'y_position': 25, 'speed': 'slow'}
print (f"Original position: {alien_0['x_position']}")

# Move the alien to the right.
# Determine how far to move the alien based on its current speed.

if alien_0['speed'] == 'slow':
    x_increment = 1
elif alien_0['speed'] == 'medium':
    x_increment = 2
else:
    x_increment = 3

alien_0['x_position'] =alien_0['x_position'] + x_increment

print (f"New position: {alien_0['x_position']}")

alien_0.get('type','No type assigned')
# Out:
# Original position: 0
# New position: 1
# 'No type assigned'

# %%
user_0 = {
'username': 'efermi',
'first': 'enrico',
'last': 'fermi',
}

# %%
for k,v in user_0.items():
    print(f"\n{k}")
    print(f"\n{v}")
# Out:
# username
#
# efermi
#
# first
#
# enrico
#
# last
#
# fermi

# %%
#Create a list containing multiple dictionaries

aliens = [] #initialize an empty list

for alien_number in range(1,31):
    new_alien = {'color': 'green', 'points': '5'}
    aliens.append(new_alien)

for alien in aliens[:5]:
    print(alien)
print(f"Total number of aliens: {len(aliens)}")
# Out:
# {'color': 'green', 'points': '5'}
# {'color': 'green', 'points': '5'}
# {'color': 'green', 'points': '5'}
# {'color': 'green', 'points': '5'}
# {'color': 'green', 'points': '5'}
# Total number of aliens: 30

# %%
# Make an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
    print("...")
# Show how many aliens have been created.
print(f"Total number of aliens: {len(aliens)}")
# Out:
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens: 30

# %%
pizza = {
    'crust': 'thick',
    'toppings':['mushrooms','extra cheese']
}

print(f"You've ordered a {pizza['crust']}-crust pizza "
      "with the following toppings:")
for topping in pizza['toppings']:
    print(f"\t {topping}")
# Out:
# You've ordered a thick-crust pizza with the following toppings:
# 	 mushrooms
# 	 extra cheese

# %%
favorite_languages = {
'jen': ['python', 'rust'],
'sarah': ['c'],
'edward': ['rust', 'go'],
'phil': ['python', 'haskell'],
}

# %%
for name,languages in favorite_languages.items():
    print(f"{name.title()}'s favourite language is:")
    for language in languages:
        print(f"{language}")
# Out:
# Jen's favourite language is:
# python
# rust
# Sarah's favourite language is:
# c
# Edward's favourite language is:
# rust
# go
# Phil's favourite language is:
# python
# haskell

# %%
users = {
'aeinstein': {
'first': 'albert',
'last': 'einstein',
'location': 'princeton',
},
'mcurie': {
'first': 'marie',
'last': 'curie',
'location': 'paris',
},
}

# %%
name = int(input("test: "))
print(name)
# Out:
# 23

# %%
responses = {}
# Set a flag to indicate that polling is active.
polling_active = True

while polling_active:
# Prompt for the person's name and response.
    name = input("\nWhat is your name? ")
    response = input("Which mountain would you like to climb someday? ")

# Store the response in the dictionary.
    responses[name] = response

# Find out if anyone else is going to take the poll.
    repeat = input("Would you like to let another person respond? (yes/ no) ")
    if repeat == 'no':
        polling_active = False

# Polling is complete. Show the results.
print("\n--- Poll Results ---")
for name, response in responses.items():
    print(f"{name} would like to climb {response}.")
# Out:
# --- Poll Results ---
# Mikolaj would like to climb Rysy.
# test would like to climb test.
# test1 would like to climb test1.

# %%
def greet_user():
    """Display a simple greeting."""
    print("Hello!")
    
greet_user()
# Out:
# Hello!

# %%
#Positional arguments

def describe_pet(animal_type, pet_name):
   """Display the information about a pet"""
   print(f"I have a {animal_type}")
   print(f"\nMy animal's name is {pet_name.title()}.")

describe_pet('dog','reksio')


#Keyword arguments

describe_pet(animal_type='dog',pet_name='reksio')

#Default Values

def describe_pet(pet_name, animal_type = 'dog'):
   """Display the information about a pet"""
   print(f"I have a {animal_type}")
   print(f"\nMy animal's name is {pet_name.title()}.")

describe_pet('reksio')
# Out:
# I have a dog
#
# My animal's name is Reksio.
# I have a dog
#
# My animal's name is Reksio.
# I have a dog
#
# My animal's name is Reksio.

# %%
#Passign a list to a function

def greet_users(names):
    for name in names:
        print(f"Hello, {name.title()}")


usernames = ['hannah','mike','john']
greet_users(usernames)
# Out:
# Hello, Hannah
# Hello, Mike
# Hello, John

# %%
def print_models(unprinted_designs, completed_models):
    """Simulate prinitng each design, unitl none are left"""
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        print(f"Prining {current_design}")
        completed_models.append(current_design)

def show_completed_models(completed_models):
    print(f"The following models where printed:")
    for completed_model in completed_models:
        print(completed_model)


unprinted_designs = ['phone case', 'robot pendant', 'dodecahedron']
completed_models = []

print_models(unprinted_designs[:] #the [:] sign passes a copy of the list to the function!
             , completed_models)
show_completed_models(completed_models)
unprinted_designs
# Out:
# Prining dodecahedron
# Prining robot pendant
# Prining phone case
# The following models where printed:
# dodecahedron
# robot pendant
# phone case
# ['phone case', 'robot pendant', 'dodecahedron']

# %%
class Dog:
    '''A simple attempt to model a dog'''

    def __init__(self, name, age):
        '''Initialize name and age attributes'''
        self.name = name
        self.age = age
    
    def sit(self):
        '''Simulate a dog sitting in reponse to a command'''
        print(f"{self.name} is now sitting.")
    def roll_over(self):
        '''Simulate a dog rolling over in sponse to a command'''
        print(f"{self.name} is not rolling over.")

# %%
my_dog = Dog('Willie',6)

# %%
my_dog.roll_over()
# Out:
# Willie is not rolling over.

# %%
class Car:
    '''A simple attempt to represent a car'''

    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
    
    def get_descriptive_name(self):
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()
    
    def read_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")

    def update_odometer(self, mileage):
        '''Set odometer to the given value'''
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer.")
    
    def increment_odometer(self, miles):
        '''Increase odometer by the given value'''
        self.odometer_reading += miles

# %%
my_car = Car('audi','a4',2024)

# %%
my_car.update_odometer(10)

# %%
my_car.increment_odometer(5)

# %%
my_car.read_odometer()
# Out:
# This car has 15 miles on it.
